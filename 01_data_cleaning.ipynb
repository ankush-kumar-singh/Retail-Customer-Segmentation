# %%
import pandas as pd

# %%
df = pd.read_excel("datasets/online_retail_II.xlsx")
df.to_csv("datasets/online_retail_II.csv", index = False)

# %%
df = pd.read_csv("datasets\online_retail_II.csv")

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.tail()
# Out:
#        Invoice StockCode                         Description  Quantity  \
# 525456  538171     22271                FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750        FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751      FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970  PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931              JUMBO STORAGE BAG SUKI         2
#
#                 InvoiceDate  Price  Customer ID         Country
# 525456  2010-12-09 20:01:00   2.95      17530.0  United Kingdom
# 525457  2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525458  2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525459  2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525460  2010-12-09 20:01:00   1.95      17530.0  United Kingdom

# %%
df.shape
# Out:
# (525461, 8)

# %%
df.size
# Out:
# 4203688

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=525461, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  object
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.1+ MB

# %%
df.describe()
# Out:
#             Quantity          Price    Customer ID
# count  525461.000000  525461.000000  417534.000000
# mean       10.337667       4.688834   15360.645478
# std       107.424110     146.126914    1680.811316
# min     -9600.000000  -53594.360000   12346.000000
# 25%         1.000000       1.250000   13983.000000
# 50%         3.000000       2.100000   15311.000000
# 75%        10.000000       4.210000   16799.000000
# max     19152.000000   25111.090000   18287.000000

# %%
df.dtypes
# Out:
# Invoice                object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# Price                 float64
# Customer ID           float64
# Country                object
# dtype: object

# %%
df["StockCode"].unique()
# df["Invoice"].unique()
# Out:
# array(['85048', '79323P', '79323W', ..., '22935', '22933', '21120'],
#       dtype=object)

# %%
df['InvoiceDate'] = pd.to_datetime(df["InvoiceDate"])

# %%
df.info()
df["InvoiceDate"].dt.time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB
# 0         07:45:00
# 1         07:45:00
# 2         07:45:00
# 3         07:45:00
# 4         07:45:00
#             ...
# 525456    20:01:00
# 525457    20:01:00
# 525458    20:01:00
# 525459    20:01:00
# 525460    20:01:00
# Name: InvoiceDate, Length: 525461, dtype: object

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
print(df["Invoice"].value_counts())
print(df["StockCode"].value_counts())


print(df["Country"].value_counts())
# print(df["Invoice"].value_counts())
# Out:
# Invoice
# 537434     675
# 538071     652
# 537638     601
# 537237     597
# 536876     593
#           ...
# C489504      1
# C489476      1
# 489467       1
# 489463       1
# C538164      1
# Name: count, Length: 28816, dtype: int64
# StockCode
# 85123A    3516
# 22423     2221
# 85099B    2057
# 21212     1933
# 21232     1843
#           ...
# 72045A       1
# 21863        1
# 21862        1
# 21052        1
# 79151B       1
# Name: count, Length: 4632, dtype: int64
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    3549
# REGENCY CAKESTAND 3 TIER              2212
# STRAWBERRY CERAMIC TRINKET BOX        1843
# PACK OF 72 RETRO SPOT CAKE CASES      1466
# ASSORTED COLOUR BIRD ORNAMENT         1457
#                                       ...
# HEN PARTY BANNER TAPE                    1
# ?sold individually?                      1
# NEW BAROQUE BLACK BOXES                  1
# SILICON CUBE 25W, BLUE                   1
# 6 HOOK JEWEL STAND LILAC DRESS           1
# ...

# %%
print(df["Description"].value_counts())
print(df["Quantity"].value_counts())
print(df["InvoiceDate"].value_counts())
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    3549
# REGENCY CAKESTAND 3 TIER              2212
# STRAWBERRY CERAMIC TRINKET BOX        1843
# PACK OF 72 RETRO SPOT CAKE CASES      1466
# ASSORTED COLOUR BIRD ORNAMENT         1457
#                                       ...
# HEN PARTY BANNER TAPE                    1
# ?sold individually?                      1
# NEW BAROQUE BLACK BOXES                  1
# SILICON CUBE 25W, BLUE                   1
# 6 HOOK JEWEL STAND LILAC DRESS           1
# Name: count, Length: 4681, dtype: int64
# Quantity
# 1       146118
# 2        78131
# 12       60682
# 6        44431
# 3        35517
#          ...
# 131          1
# 286          1
# 1540         1
# 127          1
# 133          1
# Name: count, Length: 825, dtype: int64
# InvoiceDate
# 2010-12-06 16:57:00    675
# 2010-12-09 14:09:00    652
# 2010-12-07 15:28:00    601
# 2010-12-06 09:58:00    597
# 2010-12-03 11:36:00    593
#                       ...
# ...

# %%
print(df["Price"].value_counts())
print(df["Customer ID"].value_counts())
# Out:
# Price
# 1.25       53932
# 0.85       40721
# 2.95       38094
# 1.65       35627
# 2.10       24701
#            ...
# 10.19          1
# 701.95         1
# 52.77          1
# 5519.25        1
# 183.32         1
# Name: count, Length: 1606, dtype: int64
# Customer ID
# 14911.0    5710
# 17841.0    5114
# 14606.0    3927
# 14156.0    2710
# 12748.0    2665
#            ...
# 17557.0       1
# 14190.0       1
# 13551.0       1
# 17546.0       1
# 13231.0       1
# Name: count, Length: 4383, dtype: int64

# %%
df["Invoice"].str.startswith("C").sum()
# Out:
# np.int64(10206)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
df["Customer ID"].isnull().sum()
df["Description"].isnull().sum()
# Out:
# np.int64(2928)

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
df["Description"].value_counts()
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    3549
# REGENCY CAKESTAND 3 TIER              2212
# STRAWBERRY CERAMIC TRINKET BOX        1843
# PACK OF 72 RETRO SPOT CAKE CASES      1466
# ASSORTED COLOUR BIRD ORNAMENT         1457
#                                       ...
# HEN PARTY BANNER TAPE                    1
# ?sold individually?                      1
# NEW BAROQUE BLACK BOXES                  1
# SILICON CUBE 25W, BLUE                   1
# 6 HOOK JEWEL STAND LILAC DRESS           1
# Name: count, Length: 4681, dtype: int64

# %%
df["InvoiceDate"].max()
# Out:
# Timestamp('2010-12-09 20:01:00')

# %%
df.groupby("Country")["Customer ID"].nunique().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          3971
# Germany                   67
# France                    47
# Spain                     25
# Netherlands               22
# Portugal                  18
# Belgium                   17
# Sweden                    16
# Australia                 15
# Switzerland               14
# Italy                     11
# Channel Islands           11
# Austria                   10
# Denmark                    9
# Finland                    7
# Cyprus                     7
# Japan                      6
# USA                        6
# Norway                     5
# EIRE                       5
# Unspecified                4
# United Arab Emirates       4
# Greece                     4
# Bahrain                    2
# Israel                     2
# Korea                      2
# Poland                     2
# Brazil                     1
# Singapore                  1
# Canada                     1
# Iceland                    1
# ...

# %%
(df[df["Country"] == "Bermuda"]["Customer ID"])
(df["Country"] == "Bermuda").value_counts()
# Out:
# Country
# False    525427
# True         34
# Name: count, dtype: int64

# %%
print((df[df["Country"] == "Lebanon"]["Customer ID"]))
(df["Country"] == "Lebanon").value_counts()
# Out:
# 336798   NaN
# 336799   NaN
# 336800   NaN
# 336801   NaN
# 336802   NaN
# 336803   NaN
# 336804   NaN
# 336805   NaN
# 336806   NaN
# 336807   NaN
# 336808   NaN
# 336809   NaN
# 401707   NaN
# Name: Customer ID, dtype: float64
# Country
# False    525448
# True         13
# Name: count, dtype: int64

# %%
print((df[df["Country"] == "Lebanon"]["Customer ID"]))
(df["Country"] == "Hong Kong").value_counts()
# Out:
# 336798   NaN
# 336799   NaN
# 336800   NaN
# 336801   NaN
# 336802   NaN
# 336803   NaN
# 336804   NaN
# 336805   NaN
# 336806   NaN
# 336807   NaN
# 336808   NaN
# 336809   NaN
# 401707   NaN
# Name: Customer ID, dtype: float64
# Country
# False    525385
# True         76
# Name: count, dtype: int64

# %%
df["Customer ID"].isnull().sum()
# Out:
# np.int64(107927)

# %%
df[df["Customer ID"].isna()].Country.value_counts()
# Out:
# Country
# United Kingdom          106429
# EIRE                       960
# United Arab Emirates       114
# Portugal                    77
# Hong Kong                   76
# Bahrain                     65
# France                      62
# RSA                         46
# Bermuda                     34
# Unspecified                 30
# Sweden                      19
# Lebanon                     13
# Nigeria                      2
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
df = df[~df["Invoice"].str.startswith("C")]

# %%
df["Invoice"].str.startswith("C").sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
df.shape
# Out:
# (515255, 8)

# %%
df["Invoice"].nunique()
# df["Customer ID"].nunique()
# Out:
# 24224

# %%
df[df["Customer ID"].isna()].nunique()
# Out:
# Invoice        5009
# StockCode      4405
# Description    3943
# Quantity        599
# InvoiceDate    3813
# Price          1057
# Customer ID       0
# Country          12
# dtype: int64

# %%
df["Total"] = df['Price'] * df["Quantity"]
# Out:
# C:\Users\anmol\AppData\Local\Temp\ipykernel_12032\1146084534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Total"] = df['Price'] * df["Quantity"]

# %%
total_revenue = df["Total"].sum()
print(total_revenue)
# Out:
# 10169340.004000003

# %%
Nan_revenue = df[df["Customer ID"].isna()]["Total"].sum()
print(Nan_revenue)
# Out:
# 1337336.73

# %%
(Nan_revenue/total_revenue) * 100
# Out:
# np.float64(13.150673784866793)

# %%
df["Total"].sort_values(ascending=False).unique()
# Out:
# array([ 25111.09,  15818.4 ,  13541.33, ..., -38925.87, -44031.79,
#        -53594.36])

# %%
(df["Price"] < 0).sum()
# Out:
# np.int64(3)

# %%
(df["Quantity"] < 0).sum()
# Out:
# np.int64(2121)

# %%
(df["Total"] <= 0).sum()
# Out:
# np.int64(3690)

# %%
df[df["Price"] < 0]
# Out:
#         Invoice StockCode      Description  Quantity         InvoiceDate  \
# 179403  A506401         B  Adjust bad debt         1 2010-04-29 13:36:00
# 276274  A516228         B  Adjust bad debt         1 2010-07-19 11:24:00
# 403472  A528059         B  Adjust bad debt         1 2010-10-20 12:04:00
#
#            Price  Customer ID         Country     Total
# 179403 -53594.36          NaN  United Kingdom -53594.36
# 276274 -44031.79          NaN  United Kingdom -44031.79
# 403472 -38925.87          NaN  United Kingdom -38925.87

# %%
df[df["Quantity"] < 0]
# Out:
#        Invoice StockCode   Description  Quantity         InvoiceDate  Price  \
# 263     489464     21733  85123a mixed       -96 2009-12-01 10:52:00    0.0
# 283     489463     71477         short      -240 2009-12-01 10:52:00    0.0
# 284     489467    85123A   21733 mixed      -192 2009-12-01 10:53:00    0.0
# 470     489521     21646           NaN       -50 2009-12-01 11:44:00    0.0
# 3114    489655     20683           NaN       -44 2009-12-01 17:26:00    0.0
# ...        ...       ...           ...       ...                 ...    ...
# 524458  538092     37467           NaN      -177 2010-12-09 14:49:00    0.0
# 525231  538159     21324           NaN       -18 2010-12-09 17:17:00    0.0
# 525232  538158     20892           NaN       -32 2010-12-09 17:17:00    0.0
# 525234  538161    46000S  Dotcom sales      -100 2010-12-09 17:25:00    0.0
# 525235  538162    46000M  Dotcom sales      -100 2010-12-09 17:25:00    0.0
#
#         Customer ID         Country  Total
# ...

# %%
df[df["Total"] <= 0]["Customer ID"].isna().sum()
# Out:
# np.int64(3659)

# %%
df = df[df["Customer ID"].notnull()]

# %% [markdown]
# 1.Converted InvoiceDate to datetime.
#
# 2.Created Total = Quantity × Price.
#
# 3.Identified and removed cancelled invoices (Invoice starts with C).
#
# 4.Investigated negative values and found accounting entries (Adjust bad debt).
#
# 5.Investigated descriptions and identified operational/system records.
# Separated records with missing Customer ID for customer-level analysis instead of deleting them permanently.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 407695 entries, 0 to 525460
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      407695 non-null  object
#  1   StockCode    407695 non-null  object
#  2   Description  407695 non-null  object
#  3   Quantity     407695 non-null  int64
#  4   InvoiceDate  407695 non-null  datetime64[ns]
#  5   Price        407695 non-null  float64
#  6   Customer ID  407695 non-null  float64
#  7   Country      407695 non-null  object
#  8   Total        407695 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 31.1+ MB

# %%
df.to_csv("datasets/online_retail_rfm_working_data.csv", index=False)
